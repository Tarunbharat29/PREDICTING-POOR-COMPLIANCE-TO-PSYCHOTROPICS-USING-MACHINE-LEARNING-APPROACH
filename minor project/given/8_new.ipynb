# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('df1.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 80 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Unnamed: 0                                               400 non-null    int64
#  1   name                                                     400 non-null    object
#  2   age(in years)                                            400 non-null    int64
#  3   sex                                                      400 non-null    object
#  4   district                                                 400 non-null    object
#  5   state                                                    400 non-null    object
#  6   family income per month(in Rs.)                          400 non-null    int64
#  7   referral                                                 400 non-null    object
# ...

# %%
df2 = pd.read_csv('Pilot_Variable_list_cluster 1to 8.xlsx')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 df2 = pd.read_csv('Pilot_Variable_list_cluster 1to 8.xlsx')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
import pandas as pd

xlsx_file_path = 'Pilot_Variable_list_cluster 1to 8.xlsx'
df2 = pd.read_excel(xlsx_file_path)
csv_file_path = '8originaldata.csv'
df2.to_csv(csv_file_path, index=False)
df2.head()
# Out:
#   Cluster_1_date    Date of screening         UHID            Name  \
# 0     22.06.2020  2015-02-28 00:00:00  20190021678    Akhiar Ahmed
# 1     22.06.2020  2019-05-20 00:00:00  20190008847     Mampi Shill
# 2     22.06.2020  2019-09-24 00:00:00  20190016882  Salema Khatoon
# 3     22.06.2020  2014-03-03 00:00:00  20170010718   Jiarur Rahman
# 4     22.06.2020  2020-06-18 00:00:00  20200006501   Debashis Nath
#
#    Age at presentation (in yrs)  Age at last follow up Sex (m/f)  Religion  \
# 0                          10.0                   16.0      male     Islam
# 1                           8.0                   10.0    female     Islam
# 2                          17.0                   18.0    female     Islam
# 3                           7.0                   17.0      male     Islam
# 4                          10.0                   10.0      male  Hinduism
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# ...

# %%
df2
# Out:
#           Cluster_1_date    Date of screening         UHID  \
# 0             22.06.2020  2015-02-28 00:00:00  20190021678
# 1             22.06.2020  2019-05-20 00:00:00  20190008847
# 2             22.06.2020  2019-09-24 00:00:00  20190016882
# 3             22.06.2020  2014-03-03 00:00:00  20170010718
# 4             22.06.2020  2020-06-18 00:00:00  20200006501
# ..                   ...                  ...          ...
# 187  2021-08-28 00:00:00  2020-06-24 00:00:00  20200006807
# 188  2021-08-28 00:00:00                  NaN          NaN
# 189  2021-08-28 00:00:00                  NaN          NaN
# 190  2021-08-28 00:00:00                  NaN          NaN
# 191  2021-08-28 00:00:00  2019-02-28 00:00:00  20190003397
#
#                         Name  Age at presentation (in yrs)  \
# 0               Akhiar Ahmed                          10.0
# 1                Mampi Shill                           8.0
# 2             Salema Khatoon                          17.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Columns: 274 entries, Cluster_1_date to Number of In patient cares
# dtypes: float64(8), object(266)
# memory usage: 411.1+ KB

# %%
df2.columns
# Out:
# Index(['Cluster_1_date', 'Date of screening', 'UHID', 'Name',
#        'Age at presentation (in yrs)', 'Age at last follow up', 'Sex (m/f)',
#        'Religion',
#        'Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)',
#        'Max education attained',
#        ...
#        'No of relapses/exacerbations',
#        'Off-medications duration (to add all such durations over follow-up in days)',
#        'Compliant to medications (Poor/Satisfactory/Good) (if off medications period is less than 7 days then it is considered as compliant {Poor-loss to follow up, maximum relapses,medication possession ratio < 0.9; Satisfactory- medication possession ratio 0.9 - 0.95, minimal relapse; Good- no relapse, medication possession ratio < 0.95}',
#        'mean gap ratio at lgb (total no of months of follow-up divided by no of follow-ups)',
#        'maximum period of compliance at lgb (in days) (longest streak of good compliance)',
# ...

# %%
a = df2.columns
for i in a:
    print(i)
    print()
# Out:
# Cluster_1_date
#
# Date of screening
#
# UHID
#
# Name
#
# Age at presentation (in yrs)
#
# Age at last follow up
#
# Sex (m/f)
#
# Religion
#
# Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)
#
# Max education attained
#
# Address in detail
#
# Post Office
#
# Rural/Urban
#
# Distance from LGBRIMH (in KM)
#
# District
#
# State
#
# Occupation of parents
#
# Socioeconomic status
#
# Referral
#
# Brought by
#
# Age at onset(in years)
#
# Chief complaint 1
#
# Chief complaint 2
#
# Chief complaint 3
#
# Time period between onset to first consultation at LGBRIMH (DUI) (in days)
#
# Type of Family (Nuclear/Joint/single parent/orphan/ foster family
#
# Family environment
#
# Details of family abnormality (describe)
#
# Family h/o stillbirth/abortion
#
# Family history(general medical)
#
# Family history (psychiatric/neurological)
#
# Faith healer visited before consultation or not(yes/no)
#
# Antenatal risk factor
#
# ...

# %%
df2['Name']
# Out:
# 0                 Akhiar Ahmed
# 1                  Mampi Shill
# 2               Salema Khatoon
# 3                Jiarur Rahman
# 4                Debashis Nath
#                 ...
# 187    Muzzamil Hoque Chordury
# 188              Nikhil Sonari
# 189             Rimpi Karmakar
# 190             Smiriti Barman
# 191               Ronik Barman
# Name: Name, Length: 192, dtype: object

# %%
df2['Distance from LGBRIMH (in KM)']
# Out:
# 0       53.0
# 1       62.0
# 2       55.0
# 3      102.0
# 4       29.0
#        ...
# 187     37.0
# 188      NaN
# 189      NaN
# 190      NaN
# 191     63.0
# Name: Distance from LGBRIMH (in KM), Length: 192, dtype: float64

# %%
df2['Age at presentation (in yrs)']
# Out:
# 0      10.0
# 1       8.0
# 2      17.0
# 3       7.0
# 4      10.0
#        ...
# 187    15.0
# 188     NaN
# 189     NaN
# 190     NaN
# 191     5.0
# Name: Age at presentation (in yrs), Length: 192, dtype: float64

# %%
df2['Sex (m/f)']
# Out:
# 0        male
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 187      male
# 188       NaN
# 189       NaN
# 190       NaN
# 191      male
# Name: Sex (m/f), Length: 192, dtype: object

# %%
df2['District']
# Out:
# 0        Nagaon
# 1      Udalguri
# 2        Nagaon
# 3        Nagaon
# 4      Sonitpur
#          ...
# 187      Nagaon
# 188         NaN
# 189         NaN
# 190         NaN
# 191      Nagaon
# Name: District, Length: 192, dtype: object

# %%
df2['State']
# Out:
# 0      Assam
# 1      Assam
# 2      Assam
# 3      Assam
# 4      Assam
#        ...
# 187    Assam
# 188      NaN
# 189      NaN
# 190      NaN
# 191    Assam
# Name: State, Length: 192, dtype: object

# %%
# Assuming df2 is your DataFrame
df2_cleaned = df2.dropna()

# %%
df2_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Columns: 274 entries, Cluster_1_date to Number of In patient cares
# dtypes: float64(8), object(266)
# memory usage: 0.0+ bytes

# %%
df2_cleaned
# Out:
# Empty DataFrame
# ...

# %%
df2['Name'].isnull().sum()
# Out:
# 7

# %%
df2['District'].isnull().sum()
# Out:
# 38

# %%
df2['State'].isnull().sum()
# Out:
# 38

# %%
df2['Sex (m/f)'].isnull().sum()
# Out:
# 38

# %%
df2['Age at presentation (in yrs)'].isnull().sum()
# Out:
# 38

# %%
# Assuming 'Name' is the column you want to replace null values in
df2['Name'].fillna('Not Defined', inplace=True)

# %%
df2['Name'].isnull().sum()
# Out:
# 0

# %%
df2['District'].fillna('Not Defined', inplace=True)

# %%
df2['State'].fillna('Not Defined', inplace=True)

# %%
df2['Sex (m/f)'].fillna('Not Defined', inplace=True)

# %%
df2['Age at presentation (in yrs)'].fillna(0, inplace=True)

# %%
df2['Age at presentation (in yrs)']
# Out:
# 0      10.0
# 1       8.0
# 2      17.0
# 3       7.0
# 4      10.0
#        ...
# 187    15.0
# 188     0.0
# 189     0.0
# 190     0.0
# 191     5.0
# Name: Age at presentation (in yrs), Length: 192, dtype: float64

# %%
df2['Socioeconomic status']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4      LSES
#        ...
# 187     NaN
# 188     NaN
# 189     NaN
# 190     NaN
# 191     NaN
# Name: Socioeconomic status, Length: 192, dtype: object

# %%
df2['Socioeconomic status'].isnull().sum()
# Out:
# 122

# %%
df2['Socioeconomic status'].fillna('Not Defined', inplace=True)

# %%
df2['Referral'].fillna('Not Defined', inplace=True)

# %%
df1['reason for visit']
# Out:
# 0                  Lifestyle counseling
# 1                  Medical consultation
# 2                            Counseling
# 3          Pain management consultation
# 4             Rehabilitation evaluation
#                      ...
# 395             Routine health check-up
# 396    Family health history assessment
# 397         Preventive care appointment
# 398             Routine health check-up
# 399                      Second opinion
# Name: reason for visit, Length: 400, dtype: object

# %%
import pandas as pd

xlsx_file_path = 'Pilot_Variable_list_cluster 1to 8.xlsx'
df2 = pd.read_excel(xlsx_file_path)
csv_file_path = '8originaldata.csv'
df2.to_csv(csv_file_path, index=False)
df2.head()
# Out:
#   Cluster_1_date    Date of screening         UHID            Name  \
# 0     22.06.2020  2015-02-28 00:00:00  20190021678    Akhiar Ahmed
# 1     22.06.2020  2019-05-20 00:00:00  20190008847     Mampi Shill
# 2     22.06.2020  2019-09-24 00:00:00  20190016882  Salema Khatoon
# 3     22.06.2020  2014-03-03 00:00:00  20170010718   Jiarur Rahman
# 4     22.06.2020  2020-06-18 00:00:00  20200006501   Debashis Nath
#
#    Age at presentation (in yrs)  Age at last follow up Sex (m/f)  Religion  \
# 0                          10.0                   16.0      male     Islam
# 1                           8.0                   10.0    female     Islam
# 2                          17.0                   18.0    female     Islam
# 3                           7.0                   17.0      male     Islam
# 4                          10.0                   10.0      male  Hinduism
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# ...

# %%
df2.drop('Cluster_1_date', axis=1, inplace=True)
df2.head()
# Out:
#      Date of screening         UHID            Name  \
# 0  2015-02-28 00:00:00  20190021678    Akhiar Ahmed
# 1  2019-05-20 00:00:00  20190008847     Mampi Shill
# 2  2019-09-24 00:00:00  20190016882  Salema Khatoon
# 3  2014-03-03 00:00:00  20170010718   Jiarur Rahman
# 4  2020-06-18 00:00:00  20200006501   Debashis Nath
#
#    Age at presentation (in yrs)  Age at last follow up Sex (m/f)  Religion  \
# 0                          10.0                   16.0      male     Islam
# 1                           8.0                   10.0    female     Islam
# 2                          17.0                   18.0    female     Islam
# 3                           7.0                   17.0      male     Islam
# 4                          10.0                   10.0      male  Hinduism
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# 0                                            Primary
# ...

# %%
df2.drop('UHID', axis=1, inplace=True)
df2.head()
# Out:
#      Date of screening            Name  Age at presentation (in yrs)  \
# 0  2015-02-28 00:00:00    Akhiar Ahmed                          10.0
# 1  2019-05-20 00:00:00     Mampi Shill                           8.0
# 2  2019-09-24 00:00:00  Salema Khatoon                          17.0
# 3  2014-03-03 00:00:00   Jiarur Rahman                           7.0
# 4  2020-06-18 00:00:00   Debashis Nath                          10.0
#
#    Age at last follow up Sex (m/f)  Religion  \
# 0                   16.0      male     Islam
# 1                   10.0    female     Islam
# 2                   18.0    female     Islam
# 3                   17.0      male     Islam
# 4                   10.0      male  Hinduism
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# 0                                            Primary
# 1                                                NaN
# 2                                            Primary
# ...

# %%
df2.drop('Date of screening', axis=1, inplace=True)
df2.head()
# Out:
#              Name  Age at presentation (in yrs)  Age at last follow up  \
# 0    Akhiar Ahmed                          10.0                   16.0
# 1     Mampi Shill                           8.0                   10.0
# 2  Salema Khatoon                          17.0                   18.0
# 3   Jiarur Rahman                           7.0                   17.0
# 4   Debashis Nath                          10.0                   10.0
#
#   Sex (m/f)  Religion  \
# 0      male     Islam
# 1    female     Islam
# 2    female     Islam
# 3      male     Islam
# 4      male  Hinduism
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# 0                                            Primary
# 1                                                NaN
# 2                                            Primary
# 3                                                NaN
# 4                                            primary
#
# ...

# %%
df2.drop('Religion', axis=1, inplace=True)

df2.head()
# Out:
#              Name  Age at presentation (in yrs)  Age at last follow up  \
# 0    Akhiar Ahmed                          10.0                   16.0
# 1     Mampi Shill                           8.0                   10.0
# 2  Salema Khatoon                          17.0                   18.0
# 3   Jiarur Rahman                           7.0                   17.0
# 4   Debashis Nath                          10.0                   10.0
#
#   Sex (m/f)  \
# 0      male
# 1    female
# 2    female
# 3      male
# 4      male
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# 0                                            Primary
# 1                                                NaN
# 2                                            Primary
# 3                                                NaN
# 4                                            primary
#
#   Max education attained                                  Address in detail  \
# ...

# %%
df2.drop('Address in detail', axis=1, inplace=True)
df2.head()
# Out:
#              Name  Age at presentation (in yrs)  Age at last follow up  \
# 0    Akhiar Ahmed                          10.0                   16.0
# 1     Mampi Shill                           8.0                   10.0
# 2  Salema Khatoon                          17.0                   18.0
# 3   Jiarur Rahman                           7.0                   17.0
# 4   Debashis Nath                          10.0                   10.0
#
#   Sex (m/f)  \
# 0      male
# 1    female
# 2    female
# 3      male
# 4      male
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# 0                                            Primary
# 1                                                NaN
# 2                                            Primary
# 3                                                NaN
# 4                                            primary
#
#   Max education attained     Post Office Rural/Urban  \
# ...

# %%
df2.drop('Post Office', axis=1, inplace=True)
df2.head()
# Out:
#              Name  Age at presentation (in yrs)  Age at last follow up  \
# 0    Akhiar Ahmed                          10.0                   16.0
# 1     Mampi Shill                           8.0                   10.0
# 2  Salema Khatoon                          17.0                   18.0
# 3   Jiarur Rahman                           7.0                   17.0
# 4   Debashis Nath                          10.0                   10.0
#
#   Sex (m/f)  \
# 0      male
# 1    female
# 2    female
# 3      male
# 4      male
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# 0                                            Primary
# 1                                                NaN
# 2                                            Primary
# 3                                                NaN
# 4                                            primary
#
#   Max education attained Rural/Urban  Distance from LGBRIMH (in KM)  District  \
# ...

# %%
df2.drop('District', axis=1, inplace=True)
df2.head()
# Out:
#              Name  Age at presentation (in yrs)  Age at last follow up  \
# 0    Akhiar Ahmed                          10.0                   16.0
# 1     Mampi Shill                           8.0                   10.0
# 2  Salema Khatoon                          17.0                   18.0
# 3   Jiarur Rahman                           7.0                   17.0
# 4   Debashis Nath                          10.0                   10.0
#
#   Sex (m/f)  \
# 0      male
# 1    female
# 2    female
# 3      male
# 4      male
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# 0                                            Primary
# 1                                                NaN
# 2                                            Primary
# 3                                                NaN
# 4                                            primary
#
#   Max education attained Rural/Urban  Distance from LGBRIMH (in KM)  State  \
# ...

# %%
df2.drop('State', axis=1, inplace=True)

df2.head()
# Out:
#              Name  Age at presentation (in yrs)  Age at last follow up  \
# 0    Akhiar Ahmed                          10.0                   16.0
# 1     Mampi Shill                           8.0                   10.0
# 2  Salema Khatoon                          17.0                   18.0
# 3   Jiarur Rahman                           7.0                   17.0
# 4   Debashis Nath                          10.0                   10.0
#
#   Sex (m/f)  \
# 0      male
# 1    female
# 2    female
# 3      male
# 4      male
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# 0                                            Primary
# 1                                                NaN
# 2                                            Primary
# 3                                                NaN
# 4                                            primary
#
#   Max education attained Rural/Urban  Distance from LGBRIMH (in KM)  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Columns: 266 entries, Name to Number of In patient cares
# dtypes: float64(8), object(258)
# memory usage: 399.1+ KB

# %%
column_names = df2.columns
print("Column Names:")
print(column_names)
# Out:
# Column Names:
# Index(['Name', 'Age at presentation (in yrs)', 'Age at last follow up',
#        'Sex (m/f)',
#        'Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)',
#        'Max education attained', 'Rural/Urban',
#        'Distance from LGBRIMH (in KM)', 'Occupation of parents',
#        'Socioeconomic status',
#        ...
#        'No of relapses/exacerbations',
#        'Off-medications duration (to add all such durations over follow-up in days)',
#        'Compliant to medications (Poor/Satisfactory/Good) (if off medications period is less than 7 days then it is considered as compliant {Poor-loss to follow up, maximum relapses,medication possession ratio < 0.9; Satisfactory- medication possession ratio 0.9 - 0.95, minimal relapse; Good- no relapse, medication possession ratio < 0.95}',
#        'mean gap ratio at lgb (total no of months of follow-up divided by no of follow-ups)',
# ...

# %%
pd.set_option('display.max_columns', None)
print(df2.columns)
# Out:
# Index(['Name', 'Age at presentation (in yrs)', 'Age at last follow up',
#        'Sex (m/f)',
#        'Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)',
#        'Max education attained', 'Rural/Urban',
#        'Distance from LGBRIMH (in KM)', 'Occupation of parents',
#        'Socioeconomic status',
#        ...
#        'No of relapses/exacerbations',
#        'Off-medications duration (to add all such durations over follow-up in days)',
#        'Compliant to medications (Poor/Satisfactory/Good) (if off medications period is less than 7 days then it is considered as compliant {Poor-loss to follow up, maximum relapses,medication possession ratio < 0.9; Satisfactory- medication possession ratio 0.9 - 0.95, minimal relapse; Good- no relapse, medication possession ratio < 0.95}',
#        'mean gap ratio at lgb (total no of months of follow-up divided by no of follow-ups)',
# ...

# %%
a = df2.columns
for i in a:
    print(i)
    print()
# Out:
# Name
#
# Age at presentation (in yrs)
#
# Age at last follow up
#
# Sex (m/f)
#
# Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)
#
# Max education attained
#
# Rural/Urban
#
# Distance from LGBRIMH (in KM)
#
# Occupation of parents
#
# Socioeconomic status
#
# Referral
#
# Brought by
#
# Age at onset(in years)
#
# Chief complaint 1
#
# Chief complaint 2
#
# Chief complaint 3
#
# Time period between onset to first consultation at LGBRIMH (DUI) (in days)
#
# Type of Family (Nuclear/Joint/single parent/orphan/ foster family
#
# Family environment
#
# Details of family abnormality (describe)
#
# Family h/o stillbirth/abortion
#
# Family history(general medical)
#
# Family history (psychiatric/neurological)
#
# Faith healer visited before consultation or not(yes/no)
#
# Antenatal risk factor
#
# Place of delivery (Home/hospital)
#
# Birth weight(in kg)
#
# Neonatal complication
#
# Postnatal complication
#
# Developmental history
#
# ...

# %%
df2.drop('Referral', axis=1, inplace=True)
df2.head()
# Out:
#              Name  Age at presentation (in yrs)  Age at last follow up  \
# 0    Akhiar Ahmed                          10.0                   16.0
# 1     Mampi Shill                           8.0                   10.0
# 2  Salema Khatoon                          17.0                   18.0
# 3   Jiarur Rahman                           7.0                   17.0
# 4   Debashis Nath                          10.0                   10.0
#
#   Sex (m/f)  \
# 0      male
# 1    female
# 2    female
# 3      male
# 4      male
#
#   Education at presentation (Primary 1 to 5, High school 6-10, higher secondary 11 and 12)  \
# 0                                            Primary
# 1                                                NaN
# 2                                            Primary
# 3                                                NaN
# 4                                            primary
#
#   Max education attained Rural/Urban  Distance from LGBRIMH (in KM)  \
# ...

# %%
column_name = 'Compliant to medications (Poor/Satisfactory/Good) (if off medications period is less than 7 days then it is considered as compliant {Poor-loss to follow up, maximum relapses,medication possession ratio < 0.9; Satisfactory- medication possession ratio 0.9 - 0.95, minimal relapse; Good- no relapse, medication possession ratio < 0.95}'
df2.dropna(subset=[column_name], inplace=True)
print(df2[column_name])
# Out:
# 1      Satisfactory
# 2              Poor
# 3              Good
# 4              Good
# 5      Satisfactory
#            ...
# 163            Good
# 164            Poor
# 186            Poor
# 187    Satisfactory
# 191    Satisfactory
# Name: Compliant to medications (Poor/Satisfactory/Good) (if off medications period is less than 7 days then it is considered as compliant {Poor-loss to follow up, maximum relapses,medication possession ratio < 0.9; Satisfactory- medication possession ratio 0.9 - 0.95, minimal relapse; Good- no relapse, medication possession ratio < 0.95}, Length: 148, dtype: object

# %%
df2.to_excel('df2_n.xlsx', index=False)
