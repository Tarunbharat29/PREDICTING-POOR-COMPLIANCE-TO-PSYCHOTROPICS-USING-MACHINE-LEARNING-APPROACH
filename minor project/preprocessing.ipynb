# %% [raw]
# after removing 20% null column

# %%
import numpy as np;
import pandas as pd;
import seaborn as sns;
import matplotlip as plt;

# %%
df = pd.read_csv('/home/tarun/Documents/minor project/cleaned_file.csv')

# %%
df.shape
# Out:
# (519, 262)

# %%
threshold = len(df) * 0.2

# Drop columns where the number of null values is greater than 20% of the total rows
df = df.dropna(thresh=len(df) - threshold, axis=1)

# %%
df
# Out:
#           Cluster_1_date Date of screening  Age at presentation (in yrs)  \
# 0             22.06.2020        2015-02-28                          10.0
# 1             22.06.2020        2019-05-20                           8.0
# 2             22.06.2020        2019-09-24                          17.0
# 3             22.06.2020        2014-03-03                           7.0
# 4             22.06.2020        2020-06-18                          10.0
# ..                   ...               ...                           ...
# 514  2019-10-15 00:00:00        2019-10-15                          13.0
# 515  2019-10-15 00:00:00        2019-02-08                          16.0
# 516  2019-10-15 00:00:00        2017-07-31                           2.0
# 517  2019-10-15 00:00:00        2019-10-15                           9.0
# 518  2019-10-15 00:00:00        2019-09-11                           2.6
#
#      Age at last follow up Sex (m/f)  Religion Rural/Urban  \
# ...

# %%
df.shape
# Out:
# (519, 230)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Columns: 230 entries, Cluster_1_date to Number of In patient cares
# dtypes: float64(7), object(223)
# memory usage: 932.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Columns: 230 entries, Cluster_1_date to Number of In patient cares
# dtypes: float64(7), object(223)
# memory usage: 932.7+ KB

# %%
df
# Out:
#           Cluster_1_date Date of screening  Age at presentation (in yrs)  \
# 0             22.06.2020        2015-02-28                          10.0
# 1             22.06.2020        2019-05-20                           8.0
# 2             22.06.2020        2019-09-24                          17.0
# 3             22.06.2020        2014-03-03                           7.0
# 4             22.06.2020        2020-06-18                          10.0
# ..                   ...               ...                           ...
# 514  2019-10-15 00:00:00        2019-10-15                          13.0
# 515  2019-10-15 00:00:00        2019-02-08                          16.0
# 516  2019-10-15 00:00:00        2017-07-31                           2.0
# 517  2019-10-15 00:00:00        2019-10-15                           9.0
# 518  2019-10-15 00:00:00        2019-09-11                           2.6
#
#      Age at last follow up Sex (m/f)  Religion Rural/Urban  \
# ...

# %%
pd.set_option('display.max_columns', None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Columns: 230 entries, Cluster_1_date to Number of In patient cares
# dtypes: float64(7), object(223)
# memory usage: 932.7+ KB

# %%
df.isnull().sum()
# Out:
# Cluster_1_date                                                                                        0
# Date of screening                                                                                     0
# Age at presentation (in yrs)                                                                          0
# Age at last follow up                                                                                 0
# Sex (m/f)                                                                                             0
#                                                                                                      ..
# maximum period of compliance at lgb (in days) (longest streak of good compliance)                     4
# total duration of medication treatment at LGB(in days) (from first consultation to last follow-up)    2
# frequency of follow up at lgb (to write down follow-up dates)                                         1
# ...

# %%
#finding duplicate
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#finding garbage value

df.apply(lambda x: pd.to_numeric(x, errors='coerce')).isnull().sum()
# Out:
# Cluster_1_date                                                                                        519
# Date of screening                                                                                     519
# Age at presentation (in yrs)                                                                            0
# Age at last follow up                                                                                   0
# Sex (m/f)                                                                                             519
#                                                                                                      ...
# maximum period of compliance at lgb (in days) (longest streak of good compliance)                       6
# total duration of medication treatment at LGB(in days) (from first consultation to last follow-up)      6
# frequency of follow up at lgb (to write down follow-up dates)                                         453
# ...

# %%
df.dropna()
# Out:
#           Cluster_1_date Date of screening  Age at presentation (in yrs)  \
# 4             22.06.2020        2020-06-18                          10.0
# 8             22.06.2020        2019-12-02                           3.0
# 9             22.06.2020        2019-11-11                          14.0
# 21            22.06.2020        2018-11-17                          10.0
# 23            22.06.2020        2014-07-02                          11.0
# ..                   ...               ...                           ...
# 499  2019-10-14 00:00:00        2019-10-14                           4.9
# 500  2019-10-14 00:00:00        2019-10-14                           9.0
# 506  2019-10-14 00:00:00        2019-10-14                          13.0
# 507  2019-10-14 00:00:00        2019-10-14                          11.0
# 508  2019-10-14 00:00:00        2014-09-05                           9.0
#
#      Age at last follow up Sex (m/f)  Religion Rural/Urban  \
# ...

# %%
df
# Out:
#           Cluster_1_date Date of screening  Age at presentation (in yrs)  \
# 0             22.06.2020        2015-02-28                          10.0
# 1             22.06.2020        2019-05-20                           8.0
# 2             22.06.2020        2019-09-24                          17.0
# 3             22.06.2020        2014-03-03                           7.0
# 4             22.06.2020        2020-06-18                          10.0
# ..                   ...               ...                           ...
# 514  2019-10-15 00:00:00        2019-10-15                          13.0
# 515  2019-10-15 00:00:00        2019-02-08                          16.0
# 516  2019-10-15 00:00:00        2017-07-31                           2.0
# 517  2019-10-15 00:00:00        2019-10-15                           9.0
# 518  2019-10-15 00:00:00        2019-09-11                           2.6
#
#      Age at last follow up Sex (m/f)  Religion Rural/Urban  \
# ...

# %%
a = df.columns
for i in a:
    print(i)
    print()
# Out:
# Cluster_1_date
#
# Date of screening
#
# Age at presentation (in yrs)
#
# Age at last follow up
#
# Sex (m/f)
#
# Religion
#
# Rural/Urban
#
# Distance from LGBRIMH (in KM)
#
# Age at onset(in years)
#
# Chief complaint 1
#
# Chief complaint 2
#
# Chief complaint 3
#
# Time period between onset to first consultation at LGBRIMH (DUI) (in days)
#
# Developmental history
#
# Detail of past psychiatric history 1
#
# Past treatment 1
#
# Past treatment medication 1
#
# Starting dose past medication 1
#
# Age of starting of past medication 1(in years)
#
# Past maintenance dose1 (in mg)
#
# Side effects of past medication 1
#
# Age of occurance past side effects 1(in years)
#
# Duration of past side effect 1(in months)
#
# Response to past medication 1
#
# Detail of past history 2
#
# Past treatment 2
#
# Past treatment medication 2
#
# Starting dose past medication 2
#
# Age of starting of past medication 2(in years)
#
# Past maintenance dose2
#
# Side effects of past medication 2
#
# ...

# %%
df.isnull().sum()
# Out:
# Cluster_1_date                                                                                        0
# Date of screening                                                                                     0
# Age at presentation (in yrs)                                                                          0
# Age at last follow up                                                                                 0
# Sex (m/f)                                                                                             0
#                                                                                                      ..
# maximum period of compliance at lgb (in days) (longest streak of good compliance)                     4
# total duration of medication treatment at LGB(in days) (from first consultation to last follow-up)    2
# frequency of follow up at lgb (to write down follow-up dates)                                         1
# ...

# %%
# Change Pandas display settings to show all columns
pd.set_option('display.max_columns', None)

# Now you can view all columns with missing value counts
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Cluster_1_date                                                                                        0
# Date of screening                                                                                     0
# Age at presentation (in yrs)                                                                          0
# Age at last follow up                                                                                 0
# Sex (m/f)                                                                                             0
#                                                                                                      ..
# maximum period of compliance at lgb (in days) (longest streak of good compliance)                     4
# total duration of medication treatment at LGB(in days) (from first consultation to last follow-up)    2
# frequency of follow up at lgb (to write down follow-up dates)                                         1
# ...

# %%
# Filter and display only columns that have missing values
missing_values = df.isnull().sum()
missing_columns = missing_values[missing_values > 0]
print(missing_columns)
# Out:
# Rural/Urban                                                                                            6
# Distance from LGBRIMH (in KM)                                                                         14
# Age at onset(in years)                                                                                10
# Chief complaint 2                                                                                      4
# Chief complaint 3                                                                                      9
#                                                                                                       ..
# maximum period of compliance at lgb (in days) (longest streak of good compliance)                      4
# total duration of medication treatment at LGB(in days) (from first consultation to last follow-up)     2
# frequency of follow up at lgb (to write down follow-up dates)                                          1
# ...

# %%
pd.set_option('display.max_columns', None)

# Filter and display only columns that have missing values
missing_values = df.isnull().sum()
missing_columns = missing_values[missing_values > 0]
print(missing_columns)
# Out:
# Rural/Urban                                                                                            6
# Distance from LGBRIMH (in KM)                                                                         14
# Age at onset(in years)                                                                                10
# Chief complaint 2                                                                                      4
# Chief complaint 3                                                                                      9
#                                                                                                       ..
# maximum period of compliance at lgb (in days) (longest streak of good compliance)                      4
# total duration of medication treatment at LGB(in days) (from first consultation to last follow-up)     2
# frequency of follow up at lgb (to write down follow-up dates)                                          1
# ...

# %%
# Filter only columns with missing values
missing_columns = missing_values[missing_values > 0]

# Export the missing values count to a CSV file
missing_columns.to_csv('missing_columns.csv', index=True)

print("Missing values have been saved to 'missing_columns.csv'.")
# Out:
# Missing values have been saved to 'missing_columns.csv'.

# %%
missing_value = pd.read_csv('/home/tarun/Documents/minor project/missing_columns.csv')

# %%
missing_value
# Out:
#                                             Unnamed: 0   0
# 0                                          Rural/Urban   6
# 1                        Distance from LGBRIMH (in KM)  14
# 2                               Age at onset(in years)  10
# 3                                    Chief complaint 2   4
# 4                                    Chief complaint 3   9
# ..                                                 ...  ..
# 127  maximum period of compliance at lgb (in days) ...   4
# 128  total duration of medication treatment at LGB(...   2
# 129  frequency of follow up at lgb (to write down f...   1
# 130               total number of follow up at LGBRIMH   2
# 131                         Number of In patient cares   1
#
# [132 rows x 2 columns]

# %%
chunk_size = 50
for i in range(0, len(missing_columns), chunk_size):
    print(missing_columns[i:i+chunk_size])
# Out:
# Rural/Urban                                                                                      6
# Distance from LGBRIMH (in KM)                                                                   14
# Age at onset(in years)                                                                          10
# Chief complaint 2                                                                                4
# Chief complaint 3                                                                                9
# Time period between onset to first consultation at LGBRIMH (DUI) (in days)                      12
# Developmental history                                                                          100
# Detail of past psychiatric history 1                                                            10
# Past treatment 1                                                                                 8
# ...

# %%
import pandas as pd

# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 10]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability
# Out:
#                                         Column Name  Missing Values  \
# 0                             Developmental history             100
# 1                    Severity of medical conditions              93
# 2                                    weight z score              75
# 3             systemic examination(abnormal/normal)              63
# 4  systemic examination details (main finding only)              66
# 5        Response to medication 3 (Good/partial/no)              94
# 6         Response to medication 4(Good/partial/no)              62
#
#    Missing Percentage Data Type
# 0           19.267823    object
# 1           17.919075    object
# 2           14.450867    object
# 3           12.138728    object
# 4           12.716763    object
# 5           18.111753    object
# 6           11.946050    object
# --------------------------------------------------

# %%
# Count occurrences of each category
value_counts = df['Developmental history'].value_counts(dropna=True)

# Calculate percentages
total_count = df['Developmental history'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)
# Out:
# Developmental history
# Normal                       55.369928
# Global delay                 36.754177
# Speech and language delay     4.773270
# Motor delay                   2.147971
# Socioemotional delay          0.477327
# Cognitive delay               0.477327
# Name: count, dtype: float64

# %%
# Define the categories and their probabilities
categories = ['Normal', 'Global delay', 'Speech and language delay', 
              'Motor delay', 'Socioemotional delay', 'Cognitive delay']
probabilities = [0.55369928, 0.36754177, 0.04773270, 0.02147971, 0.00477327, 0.00477327]

# Randomly fill missing values
missing_count = df['Developmental history'].isnull().sum()
random_values = np.random.choice(categories, size=missing_count, p=probabilities)
df.loc[df['Developmental history'].isnull(), 'Developmental history'] = random_values

# %%
# Count occurrences of each category
value_counts = df['Developmental history'].value_counts(dropna=True)

# Calculate percentages
total_count = df['Developmental history'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)
# Out:
# Developmental history
# Normal                       55.491329
# Global delay                 36.416185
# Speech and language delay     4.816956
# Motor delay                   2.312139
# Socioemotional delay          0.578035
# Cognitive delay               0.385356
# Name: count, dtype: float64

# %%
df['Developmental history'] = df['Developmental history'].str.lower()

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
import pandas as pd

# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 10]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability
# Out:
#                                         Column Name  Missing Values  \
# 0                    Severity of medical conditions              93
# 1                                    weight z score              75
# 2             systemic examination(abnormal/normal)              63
# 3  systemic examination details (main finding only)              66
# 4        Response to medication 3 (Good/partial/no)              94
# 5         Response to medication 4(Good/partial/no)              62
#
#    Missing Percentage Data Type
# 0           17.919075    object
# 1           14.450867    object
# 2           12.138728    object
# 3           12.716763    object
# 4           18.111753    object
# 5           11.946050    object
# --------------------------------------------------

# %%
# Count occurrences of each category
value_counts = df['Severity of medical conditions'].value_counts(dropna=True)

# Calculate percentages
total_count = df['Severity of medical conditions'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)
# Out:
# Severity of medical conditions
# Nil         95.774648
# severe       1.408451
# Mild         1.173709
# nil          0.469484
# Severe       0.469484
# Mnil         0.234742
# NIl          0.234742
# Moderate     0.234742
# Name: count, dtype: float64

# %%
df['Severity of medical condition'] = df['Severity of medical conditions'].str.lower()

# %%
df['Severity of medical conditions'] = df['Severity of medical conditions'].replace('mnil', 'mild')

# %%
# Step 2: Define the categories and their probabilities
categories = ['nil', 'severe', 'mild', 'moderate']
probabilities = [96.478873 / 100, 1.877934 / 100, 1.408451 / 100, 0.234742 / 100]  # Convert percentages to probabilities

# Step 3: Randomly fill missing values
missing_count = df['Severity of medical conditions'].isnull().sum()  # Count of missing values
random_values = np.random.choice(categories, size=missing_count, p=probabilities)  # Sample values based on probabilities

# Step 4: Fill the missing values in the DataFrame
df.loc[df['Severity of medical conditions'].isnull(), 'Severity of medical conditions'] = random_values

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 10]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability
# Out:
#                                         Column Name  Missing Values  \
# 0                                    weight z score              75
# 1             systemic examination(abnormal/normal)              63
# 2  systemic examination details (main finding only)              66
# 3        Response to medication 3 (Good/partial/no)              94
# 4         Response to medication 4(Good/partial/no)              62
# 5                     Severity of medical condition              93
#
#    Missing Percentage Data Type
# 0           14.450867    object
# 1           12.138728    object
# 2           12.716763    object
# 3           18.111753    object
# 4           11.946050    object
# 5           17.919075    object
# --------------------------------------------------

# %%
# Count occurrences of each category
value_counts = df['weight z score'].value_counts(dropna=True)

# Calculate percentages
total_count = df['weight z score'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)
# Out:
# weight z score
# 0                   18.693694
# > -1SD to < -2SD    10.585586
# > -2SD to < -3SD     9.909910
# > -3SD to < -4SD     6.531532
# 0 to 1SD             3.828829
#                       ...
# >-9SD to <-10SD      0.225225
# > -7SD to < -8SD     0.225225
# >- 2SD to < -3SD     0.225225
# > 1 SD to < -2SD     0.225225
# > 2SD to < 3SD       0.225225
# Name: count, Length: 94, dtype: float64

# %%
df['weight z score'].fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_24440/4200765858.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['weight z score'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_24440/4200765858.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['weight z score'].fillna(method='ffill', inplace=True)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Count occurrences of each category
value_counts = df['systemic examination(abnormal/normal)'].value_counts(dropna=True)

# Calculate percentages
total_count = df['systemic examination(abnormal/normal)'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)
# Out:
# systemic examination(abnormal/normal)
# Normal      86.184211
# Abnormal    13.377193
# abnormal     0.219298
# Nil          0.219298
# Name: count, dtype: float64

# %%
df['systemic examination details (main finding only)'] = df['systemic examination details (main finding only)'].str.lower()

# %%
df['systemic examination(abnormal/normal)'].replace('nil', np.nan, inplace=True)
# Out:
# /tmp/ipykernel_24440/3884715832.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['systemic examination(abnormal/normal)'].replace('nil', np.nan, inplace=True)

# %%
df['systemic examination(abnormal/normal)'].fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_24440/3249561932.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['systemic examination(abnormal/normal)'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_24440/3249561932.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['systemic examination(abnormal/normal)'].fillna(method='ffill', inplace=True)

# %%
# Count occurrences of each category
value_counts = df['systemic examination details (main finding only)'].value_counts(dropna=True)

# Calculate percentages
total_count = df['systemic examination details (main finding only)'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)
# Out:
# systemic examination details (main finding only)
# normal                                                                                      85.651214
# microcephaly                                                                                 0.662252
# pallor                                                                                       0.662252
# pallor positive                                                                              0.441501
# left sided upper motor neuron type,decrease power and  increase tone in left sided limbs     0.220751
#                                                                                               ...
# large ears, broad nasal brigde,excessive palmar crease                                       0.220751
# hump in back present, drolling of salaiva                                                    0.220751
# hearing decreased b/l ears                                                                   0.220751
# ...

# %%
df.drop(columns=['Severity of medical conditions'], inplace=True)

# %%
df['systemic examination details (main finding only)'].replace('pallor', 'pallor positive', inplace=True)
# Out:
# /tmp/ipykernel_24440/4108695863.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['systemic examination details (main finding only)'].replace('pallor', 'pallor positive', inplace=True)

# %%
df['systemic examination(abnormal/normal)'].replace('pallor', 'pallor positive', inplace=True)
# Out:
# /tmp/ipykernel_24440/3170623439.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['systemic examination(abnormal/normal)'].replace('pallor', 'pallor positive', inplace=True)

# %%
df['systemic examination details (main finding only)'].fillna('normal', inplace=True)
# Out:
# /tmp/ipykernel_24440/1372892508.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['systemic examination details (main finding only)'].fillna('normal', inplace=True)

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 10]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability
# Out:
#                                   Column Name  Missing Values  \
# 0  Response to medication 3 (Good/partial/no)              94
# 1   Response to medication 4(Good/partial/no)              62
# 2               Severity of medical condition              93
#
#    Missing Percentage Data Type
# 0           18.111753    object
# 1           11.946050    object
# 2           17.919075    object
# --------------------------------------------------

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 5]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability
# Out:
#                                          Column Name  Missing Values  \
# 0                                     weight (in Kg)              42
# 1  Mental status examination/Behavioral Observati...              30
# 2  Mental status examination/Behavioral observati...              31
# 3         Response to medication 3 (Good/partial/no)              94
# 4          Response to medication 4(Good/partial/no)              62
# 5          Response to medication 5(Good/partial/no)              36
# 6          Response to medication 6(Good/partial/no)              27
# 7                      Severity of medical condition              93
#
#    Missing Percentage Data Type
# 0            8.092486    object
# 1            5.780347    object
# 2            5.973025    object
# 3           18.111753    object
# 4           11.946050    object
# 5            6.936416    object
# 6            5.202312    object
# 7           17.919075    object
# ...

# %%
df.shape
# Out:
# (519, 230)

# %%
df.replace('nil', np.nan, inplace=True)

# %%
# Count occurrences of each category
value_counts = df['Response to medication 5(Good/partial/no)'].value_counts(dropna=True)

# Calculate percentages
total_count = df['Response to medication 6(Good/partial/no)'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)
# Out:
# Response to medication 5(Good/partial/no)
# Nil        87.601626
# Good        6.707317
# No          2.235772
# Partial     1.626016
# Name: count, dtype: float64

# %%
df['weight (in Kg)'] = pd.to_numeric(df['weight (in Kg)'], errors='coerce')

# %%
for x in df['weight (in Kg)']:
    print (x);
# Out:
# 21.0
# 20.0
# 36.0
# 15.0
# 35.0
# 21.0
# 37.0
# nan
# 20.0
# 47.0
# 45.0
# 15.0
# 12.0
# 56.0
# 18.0
# 12.0
# 37.0
# 48.0
# 13.6
# 44.0
# 9.0
# 27.0
# 10.0
# 43.0
# 65.0
# 65.0
# 44.0
# 43.0
# 27.0
# 14.0
# 21.0
# 40.0
# nan
# 48.0
# 61.8
# 41.0
# 19.0
# nan
# nan
# nan
# 50.0
# 8.0
# 46.0
# 32.0
# 34.6
# 43.0
# nan
# 40.0
# nan
# 38.0
# nan
# 10.5
# 34.0
# nan
# 20.4
# 23.0
# 30.0
# 50.0
# 40.2
# 33.0
# 12.1
# nan
# 10.0
# 20.0
# 11.0
# 10.0
# 43.0
# nan
# 26.0
# 20.0
# nan
# 45.0
# 18.0
# 34.0
# 44.0
# 42.0
# 19.0
# 17.0
# 30.0
# 10.0
# 42.0
# 10.0
# 36.0
# nan
# 24.0
# 7.0
# nan
# 36.0
# 24.0
# 40.0
# 45.0
# 41.0
# nan
# 47.0
# 38.0
# 55.0
# nan
# nan
# nan
# nan
# 14.0
# 53.0
# 16.0
# 17.0
# 23.0
# nan
# 47.0
# 41.0
# 39.0
# 55.0
# 15.0
# 40.0
# nan
# 53.0
# 19.0
# 29.0
# 27.0
# 14.0
# 25.0
# 50.0
# 48.0
# 46.0
# 32.0
# 24.0
# 54.0
# 39.0
# 30.0
# 24.0
# 37.0
# 70.0
# 64.0
# 23.0
# 46.0
# 24.0
# 20.0
# 55.0
# nan
# 22.0
# 15.0
# 38.0
# 27.0
# 10.0
# 21.0
# 53.0
# 30.0
# 51.0
# ...

# %%
# Count occurrences of each category
value_counts = df['Response to medication 6(Good/partial/no)'].value_counts(dropna=True)

# Calculate percentages
total_count = df['Response to medication 6(Good/partial/no)'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)
# Out:
# Response to medication 6(Good/partial/no)
# Nil        94.105691
# Good        3.861789
# Partial     1.016260
# No          1.016260
# Name: count, dtype: float64

# %%
df['Response to medication 5(Good/partial/no)'].fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_24440/1881218910.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Response to medication 5(Good/partial/no)'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_24440/1881218910.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Response to medication 5(Good/partial/no)'].fillna(method='ffill', inplace=True)

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 5]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability
# Out:
#                                          Column Name  Missing Values  \
# 0                                     weight (in Kg)              44
# 1  Mental status examination/Behavioral Observati...              30
# 2  Mental status examination/Behavioral observati...              31
# 3         Response to medication 3 (Good/partial/no)              96
# 4          Response to medication 4(Good/partial/no)              62
# 5          Response to medication 6(Good/partial/no)              27
# 6                      Severity of medical condition             504
#
#    Missing Percentage Data Type
# 0            8.477842   float64
# 1            5.780347    object
# 2            5.973025    object
# 3           18.497110    object
# 4           11.946050    object
# 5            5.202312    object
# 6           97.109827    object
# --------------------------------------------------

# %%
df['Response to medication 6(Good/partial/no)'].fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_24440/1651954551.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Response to medication 6(Good/partial/no)'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_24440/1651954551.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Response to medication 6(Good/partial/no)'].fillna(method='ffill', inplace=True)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Count occurrences of each category
value_counts = df['Mental status examination/Behavioral observation details (main finding only in description)'].value_counts(dropna=True)

# Calculate percentages
total_count = df['Mental status examination/Behavioral observation details (main finding only in description)'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)
# Out:
# Mental status examination/Behavioral observation details (main finding only in description)
# Normal                                                                         19.262295
# normal                                                                          2.254098
# Rapport not established                                                         2.049180
# Anxious affect                                                                  1.229508
# Insight grade- 1                                                                0.614754
#                                                                                  ...
# shouting,restless,irritable,not responding to questions                         0.204918
# Restless, physically abusive,delayed speech,demanding,poor in academic          0.204918
# Apprehension about future                                                       0.204918
# absent eye contact, decreased PMA, delusion of persecution, insight grade 2     0.204918
# ...

# %%
df['Mental status examination/Behavioral observation details (main finding only in description)'].fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_24440/3111549672.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Mental status examination/Behavioral observation details (main finding only in description)'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_24440/3111549672.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# ...

# %%
# Count occurrences of each category
value_counts = temp.value_counts(dropna=True)

# Calculate percentages
total_count = temp.count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 # Count occurrences of each category
# ----> 2 value_counts = temp.value_counts(dropna=True)
#       4 # Calculate percentages
#       5 total_count = temp.count()  # Total non-null entries
#
# NameError: name 'temp' is not defined

# %%
df['Mental status examination/Behavioral observation details (main finding only in description)'] = df['Mental status examination/Behavioral observation details (main finding only in description)'].str.lower()

# %%
df.replace('nil', np.nan, inplace=True)

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 4]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability

# %%
sns.heatmap(df.isnull())

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 10]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability

# %%
# Count occurrences of each category
value_counts = df['Response to medication 3 (Good/partial/no)'].value_counts(dropna=True)

# Calculate percentages
total_count = df['Response to medication 3 (Good/partial/no)'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)

# %%
df.replace('Nil', np.nan, inplace=True)

# %%
# Count occurrences of each category
value_counts = df['Response to medication 3 (Good/partial/no)'].value_counts(dropna=True)

# Calculate percentages
total_count = df['Response to medication 3 (Good/partial/no)'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 20]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability

# %%
import pandas as pd

# Step 1: Load the CSV file into a DataFrame (if you have it in a CSV)
# df = pd.read_csv('your_file.csv')

# Step 2: Calculate the threshold for dropping columns (20% null values)
threshold = 0.20 * len(df)  # This calculates 20% of the total rows

# Step 3: Drop columns with more than 20% null values
df = df.dropna(thresh=len(df) - threshold, axis=1)

# Print the updated DataFrame
print(df)

# Optionally, save the updated DataFrame back to a CSV file
# df.to_csv('your_file_updated.csv', index=False)

# %%
df.shape

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 20]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability

# %%
df

# %%
sns.heatmap(df.isnull())

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 10]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability

# %%
# Count occurrences of each category
value_counts = df['Chief complaint 2'].value_counts(dropna=True)

# Calculate percentages
total_count = df['Chief complaint 2'].count()  # Total non-null entries
percentages = (value_counts / total_count) * 100

# Display the result
print(percentages)

# %%
df['Chief complaint 2'].fillna(method = 'ffill' , inplace = True)

# %%
# Calculate missing values for each column
missing_values = df.isnull().sum()

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(df)) * 100

# Filter columns with missing values less than 10%
filtered_columns = missing_percentage[missing_percentage > 5]

# Get the data types of the filtered columns
filtered_column_types = df.dtypes[filtered_columns.index]

# Combine column names, missing values, percentages, and data types into a DataFrame
missing_info = pd.DataFrame({
    'Column Name': filtered_columns.index,
    'Missing Values': missing_values[filtered_columns.index].values,
    'Missing Percentage': filtered_columns.values,
    'Data Type': filtered_column_types.values
})

# Display in chunks of 50
chunk_size = 50
for i in range(0, len(missing_info), chunk_size):
    print(missing_info.iloc[i:i + chunk_size])
    print('-' * 50)  # Separator for readability

# %%
df_temp = df.fillna(method = 'ffill')

# %%
sns.heatmap(df_temp.isnull())

# %%
df_temp.info

# %%
df_temp.columns

# %%
df

# %%
df_temp

# %%
df_temp.dtypes

# %%
df_temp

# %%
#df_temp['Cluster_1_date'] = pd.to_datetime(df_temp['Cluster_1_date'])

# %%
# Specify the path to save the Excel file with the correct extension
excel_file_path = '/home/tarun/Documents/minor project/after_no_null_values.xlsx'  # Ensure the file extension is .xlsx

# Convert DataFrame to Excel
df.to_excel(excel_file_path, index=False)  # index=False to avoid writing row indices

print(f"DataFrame has been written to '{excel_file_path}'")
